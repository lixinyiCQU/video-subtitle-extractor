# %% [markdown]
# # Video Subtitle Extractor - Colab GPU
#
# Run the cells below, then open the Gradio public URL printed by the last cell.

# %%
# Optional: mount Google Drive for persistent HuggingFace model cache.
# Leave this commented if you prefer Colab's temporary disk.
# from google.colab import drive
# drive.mount('/content/drive')
# import os
# os.environ['HF_HOME'] = '/content/drive/MyDrive/hf_cache'
# os.environ['HF_HUB_CACHE'] = '/content/drive/MyDrive/hf_cache/hub'

import os
os.environ['HF_HUB_DISABLE_SYMLINKS_WARNING'] = '1'

# %%
# !rm -rf /content/video-subtitle-extractor
# !git clone https://github.com/lixinyiCQU/video-subtitle-extractor.git /content/video-subtitle-extractor
# %cd /content/video-subtitle-extractor
# !python -m pip install --upgrade -r requirements.txt

# %%
# Gradio will print a public share URL. Use that URL from your browser.
# !python gradio_app.py --share --server-name 0.0.0.0 --server-port 7860
